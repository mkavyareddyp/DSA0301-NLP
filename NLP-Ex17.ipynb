# %% [markdown]
# <a href="https://colab.research.google.com/github/mkavyareddyp/DSA0301-NLP/blob/main/NLP-Ex17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk.corpus import wordnet

nltk.download('wordnet')

word = "bank"

synsets = wordnet.synsets(word)

for syn in synsets[:5]:
    print("Synset:", syn.name())
    print("Definition:", syn.definition())
    print()
# Out:
# Synset: bank.n.01
# Definition: sloping land (especially the slope beside a body of water)
#
# Synset: depository_financial_institution.n.01
# Definition: a financial institution that accepts deposits and channels the money into lending activities
#
# Synset: bank.n.03
# Definition: a long ridge or pile
#
# Synset: bank.n.04
# Definition: an arrangement of similar objects in a row or in tiers
#
# Synset: bank.n.05
# Definition: a supply or stock held in reserve for future use (especially in emergencies)
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
