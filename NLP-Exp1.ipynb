# %% [markdown]
# <a href="https://colab.research.google.com/github/mkavyareddyp/DSA0301-NLP/blob/main/NLP-Exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re

text = "My email is kavya@gmail.com and my phone is 9876543210."

email = re.search(r'[\w.-]+@[\w.-]+\.\w+', text)
phone = re.search(r'\b\d{10}\b', text)

print("Text:", text)
print("Email:", email.group() if email else "Not found")
print("Phone:", phone.group() if phone else "Not found")

words = re.findall(r'\b[A-Za-z]+\b', text)
print("Words:", words)
# Out:
# Text: My email is kavya@gmail.com and my phone is 9876543210.
# Email: kavya@gmail.com
# Phone: 9876543210
# Words: ['My', 'email', 'is', 'kavya', 'gmail', 'com', 'and', 'my', 'phone', 'is']
