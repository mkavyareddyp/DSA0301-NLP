# %% [markdown]
# <a href="https://colab.research.google.com/github/mkavyareddyp/DSA0301-NLP/blob/main/NLP-Exp5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()

words = ["playing", "played", "studies", "connection", "easily"]

for word in words:
    print(word, "->", stemmer.stem(word))
# Out:
# playing -> play
# played -> play
# studies -> studi
# connection -> connect
# easily -> easili
