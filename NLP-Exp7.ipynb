# %% [markdown]
# <a href="https://colab.research.google.com/github/mkavyareddyp/DSA0301-NLP/blob/main/NLP-Exp7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk

text = "The boy is playing football in the ground."

words = nltk.word_tokenize(text)

tags = nltk.pos_tag(words)

print("Word -> POS Tag")

for word, tag in tags:
    print(word, "->", tag)
# Out:
# Word -> POS Tag
# The -> DT
# boy -> NN
# is -> VBZ
# playing -> VBG
# football -> NN
# in -> IN
# the -> DT
# ground -> NN
# . -> .
