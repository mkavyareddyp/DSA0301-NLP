# %% [markdown]
# <a href="https://colab.research.google.com/github/mkavyareddyp/DSA0301-NLP/blob/main/NLP-Exp10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
words = ["I", "am", "playing", "football"]

tags = ["NN", "NN", "NN", "NN"]

print("Before transformation:")
print(list(zip(words, tags)))

# Transformation rules
for i, word in enumerate(words):
    if word.lower() == "i":
        tags[i] = "PRP"
    if word.lower() in ["am", "is", "are"]:
        tags[i] = "VBP"
    if word.endswith("ing"):
        tags[i] = "VBG"

print("\nAfter transformation:")
print(list(zip(words, tags)))
# Out:
# Before transformation:
# [('I', 'NN'), ('am', 'NN'), ('playing', 'NN'), ('football', 'NN')]
#
# After transformation:
# [('I', 'PRP'), ('am', 'VBP'), ('playing', 'VBG'), ('football', 'NN')]
