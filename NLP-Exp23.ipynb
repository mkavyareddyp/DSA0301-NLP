# %% [markdown]
# <a href="https://colab.research.google.com/github/mkavyareddyp/DSA0301-NLP/blob/main/NLP-Exp23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

text = [
    "Python is a programming language.",
    "Python is widely used for machine learning.",
    "Machine learning is a branch of artificial intelligence."
]

vectorizer = TfidfVectorizer()
matrix = vectorizer.fit_transform(text)

similarity = cosine_similarity(matrix)

score = (similarity[0][1] + similarity[1][2]) / 2

print("Coherence Score:", round(score, 3))

if score > 0.1:
    print("Text is reasonably coherent")
else:
    print("Text has low coherence")
# Out:
# Coherence Score: 0.262
# Text is reasonably coherent
