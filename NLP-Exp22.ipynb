# %% [markdown]
# <a href="https://colab.research.google.com/github/mkavyareddyp/DSA0301-NLP/blob/main/NLP-Exp22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk
from nltk import word_tokenize

nltk.download('punkt')
nltk.download('punkt_tab')

sentence = "Ravi went to the library because he wanted to read a book."

words = word_tokenize(sentence)

for i, word in enumerate(words):
    if word.lower() in ["he", "she", "it", "they"]:
        for j in range(i - 1, -1, -1):
            if words[j][0].isupper():
                print("Pronoun:", word)
                print("Refers to:", words[j])
                break
# Out:
# Pronoun: he
# Refers to: Ravi
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
